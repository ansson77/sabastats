# %% [markdown]
# The purpose of this notebook to draw different graphs based on the data scraped from fliiga.com

# %%
from hockey_rink import *
import matplotlib.pyplot as plt

# %%
rink = NHLRink(red_line={'feature_class': RinkRectangle,
                         'color': 'black'},
                blue_line={'feature_class':RinkRectangle,
                          'visible': False},
                goal_line={'feature_class': RinkRectangle,
                           'visible': False},
                trapezoid={'feature_class': TrapezoidLine,
                           'visible': False},
                ref_circle={'feature_class': RinkCircle,
                            'visible': False},
                center_circle={'feature_class': RinkCircle,
                               'visible': False},
                faceoff_circle={'feature_class': FaceoffCircle,
                                'visible': False},
                faceoff_dot={'feature_class': FaceoffDot,
                             'visible': False},
                faceoff_lines={'feature_class': RinkL,
                               'visible': False},
                crease={'feature_class': Crease,
                        'length': 5,
                        'width': 8,
                        'thickness': 0.5,
                        'color': 'blue'},
                crease_outline={'feature_class': Crease,
                                'visible': False},
                boards={'radius': 10}
               )

rink_2 = NHLRink()
fig, ax = plt.subplots(1, 2, figsize=(20,10))
rink.draw(ax=ax[0])
rink_2.draw(ax=ax[1])
ax[1] = rink_2.draw()
plt.show()
